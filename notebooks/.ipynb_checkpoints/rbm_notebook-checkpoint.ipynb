# %% [markdown]
# # About RBMs
#
# Let us assume we have $d$ visible units and $n$ hidden units.
#
#
# Energy of an RBM
#
# $$
# E(v,h) = - b^Tv - c^Th - h^t W v
# $$
#
# Probability of an assignment of hidden and visible units:
#
# $$
# P(v,h) = - \frac{ e^{-E(v,h)} } { \sum_{( \bar{v},\bar{h}) \in \{0,1\}^d x \{0,1\}^n } e^{-E(\bar{v},\bar{h})} }
# $$

# %%
import sys
sys.path.insert(0,'..')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from timeit import default_timer as timer
import numpy as np
import time
import matplotlib.pyplot as plt
import numexpr  as ne
import profile
import RBM
from RBM import rbm
import pandas
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Read the MNIST without labels

# %%
X = pandas.read_csv("../Datasets/MNIST/test_mnist.csv").values
X_ = pandas.read_csv("../Datasets/MNIST/train_mnist.csv")
X_= X_[X_.columns[1:]].values
X = np.concatenate((X, X_), axis=0) 
del(X_)

print('\t files read')
X = np.array(X>4, dtype ='float32')

saved_models_folder = "saved_models"
visible_dim = X.shape[1]
hidden_dim = 225
epochs = 100
K = 1
lr = 0.1
batch_size = 500

Xaux = np.array(X, dtype='float32')
# Out:
# 	 files read

# %% [markdown]
# ## Define an RBM and train it

# %%
rbm_ = rbm.RBM(visible_dim=visible_dim,
               hidden_dim=hidden_dim,
               seed=42,
               mu=0, 
               sigma=0.3,
               monitor_time=True)

# %%
rbm_.fit(Xaux, 
         method='CDK_vectorized_numexpr',
         K=K,
         lr=lr,
         epochs=epochs,
         batch_size=batch_size,
         plot_weights=False)
# Out:
# epoch 99/ 100	time per epoch: 3.97	 total time: 403.18

# %% [markdown]
# ## Plot the weights after training

# %%
rbm_.plot_weights()

# %% [markdown]
# ## Profiling the code
#
# from the terminal execute
# ```
#  python -m cProfile -o rbm_main.profile rbm_main.py
# ```
#
# This command will create a text file rbm_final_numexp.profile with the information about the profiling of the code.
#
# -  We can load the profiling later with pstats to check how our code is utilizing time

# %%
python -m cProfile -o rbm_main.profile ../rbm_main.py
# Out:
#   File "<ipython-input-37-a27cb9345c8a>", line 1
#     python -m cProfile -o rbm_main.profile ../rbm_main.py
#                      ^
# SyntaxError: invalid syntax

# %%
.run
# Out:
#   File "<ipython-input-39-982db52dd2e1>", line 1
#     .run
#     ^
# SyntaxError: invalid syntax

# %%
import pstats

p = pstats.Stats('rbm_final_numexp.profile')
p.sort_stats('time') # 'calls' etc
p.print_stats(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-2db2b443bf36> in <module>()
#       1 import pstats
#       2
# ----> 3 p = pstats.Stats('rbm_final_numexp.profile')
#       4 p.sort_stats('time') # 'calls' etc
#       5 p.print_stats(10)
#
# /Users/macpro/anaconda/lib/python3.5/pstats.py in __init__(self, stream, *args)
#      67             arg = args[0]
#      68             args = args[1:]
# ---> 69         self.init(arg)
#      70         self.add(*args)
#      71
#
# /Users/macpro/anaconda/lib/python3.5/pstats.py in init(self, arg)
#      81         self.stats = {}
#      82         self.sort_arg_dict = {}
# ---> 83         self.load_stats(arg)
#      84         try:
#      85             self.get_top_level_stats()
#
# /Users/macpro/anaconda/lib/python3.5/pstats.py in load_stats(self, arg)
#      94             return
#      95         elif isinstance(arg, str):
# ---> 96             with open(arg, 'rb') as f:
#      97                 self.stats = marshal.load(f)
#      98             try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rbm_final_numexp.profile'

# %% [markdown]
# ## Related papers
#
# #### Investigating convergence of RBM learning:
# - http://www.ais.uni-bonn.de/papers/nips10ws_schulz_mueller_behnke.pdf

# %% [markdown]
# ## Interesting material
#
#
# Some sources and interesting information:
#
#
# #### Annealed Importance Sampling
# - http://www.cs.toronto.edu/pub/radford/ais-rev.pdf
#
# #### Approximate inference MIT deep learning:
# - http://goodfeli.github.io/dlbook/version-2015-10-18/contents/inference.html
#
# #### Confronting the Partition Function:
# - http://goodfeli.github.io/dlbook/version-2015-10-18/contents/partition.html
